# %% [markdown]
# # Email Reply Model Training
#
# This notebook trains the email reply generation model using the Email Conversation Dataset.

# %%
import pandas as pd
import pickle
from pathlib import Path

# Load dataset
df = pd.read_csv('../data/email_dataset.csv')
print(f'Dataset shape: {df.shape}')
df.head()

# %%
# --- Fine-tune a T5 model for email reply generation ---
# Replace this section with your actual training code
from transformers import T5ForConditionalGeneration, T5Tokenizer

model_name = 't5-small'
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

print('Model loaded. Add training loop here.')

# %%
# Save model
Path('../models').mkdir(exist_ok=True)
with open('../models/email_reply_model.pkl', 'wb') as f:
    pickle.dump(model, f)
print('Model saved to models/email_reply_model.pkl')
